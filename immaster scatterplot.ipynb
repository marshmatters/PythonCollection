# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import pandas as pd
import time
import numpy as np
from sklearn.cluster import KMeans
from sklearn import preprocessing, cross_validation

counter = 1

def job():
    """print ("hello world)
    print (counter)"""
    time.sleep(1)

while counter < 5:
    job()
    counter = 1 + counter
else:
    """print("last counter 5")"""

# %%
df = pd.read_csv("scattersample.csv")

# %%
df
# Out:
#       ITEM TITLE_SKU           MFGSKU PRODTYPE  \
# 0   736202    737798  EXMPI550000-GOV      G-L
# 1   749146    987103            16630      N-L
# 2   818746    A17203           NSS100      E-L
# 3   UG6639    396012         210-AENO        N
# 4   959017    191366           HYE005      N-L
# 5   UG6640    Y25840       500213-001      N-L
# 6   A96278    980398   SCRT-0009-0500      N-L
# 7   B34296    A30269   SCTB-0071-0500    N-LSA
# 8   B34298    184901   SFXX-0066-0002    N-LSA
# 9   B44225    B44113          NSP0100      E-L
# 10  B63025    B54559             SJNT     N-SA
# 11  B70307    B55803     EBSYCM-AM-DA     N-SA
# 12  B84449    951461            60872      N-L
# 13  C09218    B25673            22001        N
# 14  C09221    A29576            14005      N-L
# 15  C57812    B39043  PIX-515E-UR-BUN        N
# 16  C44872    B33222          MPPD050     N-SA
# 17  C62981    B77841     623-MNT-E-US     N-SA
# 18  C60445    204703     AT-FS724I-10        N
# 19  C74486    B77306           317221     N-SA
# 20  C99021    B44990             M884     N-SA
# 21  D19773    B96523   CPFW-FIG-25-NG      N-L
# 22  D19785    B96544     CPFW-FM-U-NG      N-L
# 23  D18544    A70443     436-MNT-E-US     N-SA
# 24  D35391    B97635        10010723S     N-SA
# 25  D31312    C01928             RBC7        N
# 26  D70767    214866          DSP-400        N
# 27  D80723    C23768        10070021S     E-SA
# 28  D86727    C25191    EXMPI550101MD     N-SA
# 29  D89229    C26356         SLW00400      N-L
# 30  D88675    C29093          LAMAINT     N-SA
#
#                                  CATEGORY                    SUB_CATEGORY
# 0                               Utilities            desktop enhancements
# 1                   Business applications      databases / database tools
# 2                   Education application             learning management
# 3                                 Systems                        Desktops
# 4                               Utilities  hardware & software optimizing
# 5                                Software                    Applications
# 6                 Networking applications   remote access / login control
# 7                 Networking applications   remote access / login control
# 8                   Security applications                 data encryption
# 9                   Education application                           other
# 10                               Software      Software Service & Support
# 11                               Software      Software Service & Support
# 12                      Development tools                      RAD suites
# 13                    Office applications              projects / process
# 14                    Office applications              projects / process
# 15                             Networking                 Network Devices
# 16                              Utilities                           other
# 17                               Software      Software Service & Support
# 18                             Networking                 Hubs & Switches
# 19                      Development tools                      team tools
# 20                              Utilities             document management
# 21                  Security applications                desktop firewall
# 22                  Security applications   remote access / login control
# 23                               Software      Software Service & Support
# 24                 Creativity application         web design / publishing
# 25                                Systems             UPS & Power Devices
# 26                                  Audio          Headsets & Microphones
# 27                 Creativity application         web design / publishing
# 28                Networking applications     connectivity & data sharing
# 29  Internet & communication applications              internet utilities
# 30                Networking applications      system & remote management

# %%
df.drop(['ITEM','TITLE_SKU', 'MFGSKU', 'SUB_CATEGORY'], 1, inplace=True)

# %%
df
# Out:
#    PRODTYPE                               CATEGORY
# 0       G-L                              Utilities
# 1       N-L                  Business applications
# 2       E-L                  Education application
# 3         N                                Systems
# 4       N-L                              Utilities
# 5       N-L                               Software
# 6       N-L                Networking applications
# 7     N-LSA                Networking applications
# 8     N-LSA                  Security applications
# 9       E-L                  Education application
# 10     N-SA                               Software
# 11     N-SA                               Software
# 12      N-L                      Development tools
# 13        N                    Office applications
# 14      N-L                    Office applications
# 15        N                             Networking
# 16     N-SA                              Utilities
# 17     N-SA                               Software
# 18        N                             Networking
# 19     N-SA                      Development tools
# 20     N-SA                              Utilities
# 21      N-L                  Security applications
# 22      N-L                  Security applications
# 23     N-SA                               Software
# 24     N-SA                 Creativity application
# 25        N                                Systems
# 26        N                                  Audio
# 27     E-SA                 Creativity application
# 28     N-SA                Networking applications
# 29      N-L  Internet & communication applications
# 30     N-SA                Networking applications

# %%
def handle_non_numerical_data(df):
    columns = df.columns.values
    
    for column in columns:
        text_digit_vals = {} 
        def convert_to_int(val):
            return text_digit_vals[val]
        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x+=1
            df[column] = list(map(convert_to_int, df[column]))
        
    return df
df = handle_non_numerical_data(df)

# %%
df
# Out:
#     PRODTYPE  CATEGORY
# 0          0         6
# 1          5         3
# 2          6         2
# 3          3         0
# 4          5         6
# 5          5         7
# 6          5         5
# 7          1         5
# 8          1         1
# 9          6         2
# 10         2         7
# 11         2         7
# 12         5        12
# 13         3         9
# 14         5         9
# 15         3        10
# 16         2         6
# 17         2         7
# 18         3        10
# 19         2        12
# 20         2         6
# 21         5         1
# 22         5         1
# 23         2         7
# 24         2        11
# 25         3         0
# 26         3         8
# 27         4        11
# 28         2         5
# 29         5         4
# 30         2         5
